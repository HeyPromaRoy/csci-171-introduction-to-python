# %% [markdown]
# # CSCI 171 — Introduction to Python
#
# ## Homework Assignment 1: Computers, Colab Notebooks, and Variables and Basic Types
#
# **Instructor:** Proma Roy
# **Term:** Fall 2026
# **Covers:** Meeting 1 (Computers, Programs, Python, and Google Colab), Meeting 2 (Your First Google Colab Notebook), and Meeting 3 (Variables and Basic Data Types)
# **Due date:** See the assignment posting on Brightspace
#
# [![Open this assignment in Google Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HeyPromaRoy/csci-171-introduction-to-python/blob/main/homework/01_computers_colab_and_variables_preview.ipynb)
#
# > **What this is:** This is a short reinforcement homework, separate from the four graded Programming Assignments described in the syllabus (Assignment 1 there begins in Week 3). Check Brightspace for how this assignment counts toward your grade and for the exact due date.

# %% [markdown]
# ## How to complete and submit this notebook
#
# 1. Open this notebook with the **Open in Google Colab** badge above.
# 2. Immediately select **File → Save a copy in Drive**, then move the copy into `CSCI 171 - Fall 2026/03_Assignments`.
# 3. Rename the copy `HW1_lastname_firstname.ipynb`.
# 4. Replace every placeholder (`?`, `_Write your answer here._`, `Replace with your name`) with your own work.
# 5. Before submitting, use Colab's **Runtime → Restart runtime and run all** and confirm every cell runs without an unintended error.
# 6. Submit the requested file or link through Brightspace according to the instructions posted there.
#
# **Academic integrity:** Complete this assignment yourself. Any permitted AI use must be disclosed in an AI-use note at the end of the notebook, following the format in the course syllabus (tool, date, purpose, and prompt). You must be able to explain every line you submit.

# %% [markdown]
# ## Learning goals
#
# By the end of this assignment, you should be able to:
#
# - Explain hardware vs. software and the roles of the CPU, memory, storage, input, and output in your own words.
# - Explain what a notebook file is and how it differs from the temporary runtime that executes its code.
# - Write and run code cells with `print`, and diagnose and repair a `NameError` caused by using a name before it is created.
# - Create variables of type `int`, `float`, `str`, and `bool`, and use `type()` to verify each one.

# %% [markdown]
# ## Part A — Computers, Software, and the CPU/Memory/Storage System
#
# *Based on Meeting 1 and its pre-class reading.*
#
# Answer each question in complete sentences. Use an example from your own life or a program you actually use — not the restaurant-kitchen example from class.

# %% [markdown]
# **A1.** Name one hardware item and one software item you used in the last 24 hours. Explain, in your own words, why each one is hardware or software rather than the other.

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# **A2.** Pick one app or website you use regularly (for example, a ride-share app, a vending machine, or a streaming service). Identify one input, describe the processing step in plain language, and identify one output.

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# **A3.** Invent your own analogy (not the class kitchen analogy) that distinguishes memory (RAM) from storage. Explain why your analogy captures the fact that memory is temporary while storage is long term.

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# ## Part B — Notebooks, Runtime State, and Print
#
# *Based on Meeting 2 and its pre-class reading.*
#
# Run the next cell exactly as written.

# %%
print("Homework author:", student_name)
student_name = "Replace with your name"

# %% [markdown]
# **B1.** What error did Python raise, and why did it happen? Answer in the next cell before you fix anything.

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# Now write a corrected version below. Keep both lines, but place them in an order that lets the cell run without an error, and replace the placeholder text with your actual name.

# %%
# TODO: write a corrected, working version of the two lines above

# %% [markdown]
# **B2.** Describe yourself with variables. In the next cell, create four variables: a `str` for your favorite subject, an `int` for your usual hours of sleep, a `float` for a GPA goal this semester, and a `bool` for whether you have used Python before. Print each value with a label, followed by its type using `type()`.

# %%
# TODO: create the four variables described above
favorite_subject = "?"
hours_of_sleep = 0
gpa_goal = 0.0
has_used_python_before = False

# TODO: print each value with a label, and its type

# %% [markdown]
# **B3.** Use Colab's **Runtime** menu to restart the runtime and run all cells from the top. In one or two sentences, confirm whether every cell ran successfully in order, and describe anything you had to change to make that true.

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# ## Part C — Variables and Basic Data Types
#
# *Based on Meeting 3 and its pre-class reading.*

# %% [markdown]
# **C1.** Without running any code, predict the type Python would report for each value below: `int`, `float`, `str`, or `bool`. Fill in the "Your prediction" column.
#
# | Value | Your prediction | Confirmed with `type()`? |
# |---|---|---|
# | `42` | _?_ | |
# | `42.0` | _?_ | |
# | `"42"` | _?_ | |
# | `True` | _?_ | |
# | `"True"` | _?_ | |

# %% [markdown]
# Now check each prediction. Complete the code below so it prints the type of every value in the table.

# %%
# TODO: print the type of each value from the table above
print(type(42))

# %% [markdown]
# **C2.** Model a short personal profile using the reading's four basic types. In the next cell, create variables for: your favorite course (`str`), your age (`int`), the current outdoor temperature in your city (`float`), and whether you are registered for CSCI 171 (`bool`). Print each value with a label, and its type.

# %%
# TODO: replace each placeholder with an appropriate value
favorite_course = "?"
age = 0
outdoor_temperature = 0.0
is_registered_for_csci171 = False

# TODO: print each value with a label, and its type

# %% [markdown]
# **C3.** The Meeting 3 reading states that `8` is a number while `"8"` is text, even though they look similar to a person. In your own words, why might Python need to treat these differently, and what could go wrong if it did not?

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# ## Reflection
#
# Answer each question in one or two complete sentences.
#
# 1. Which part of this assignment did you feel most confident about, and why?
# 2. Which part are you least sure about? Write one specific question about it that you could ask in the next class or during office hours.
# 3. **AI-use note:** State "No AI tools were used on this assignment," or disclose any permitted AI use following the syllabus format (tool, date, purpose, and prompt).

# %% [markdown]
# _Write your answers here._

# %% [markdown]
# ## Submission checklist
#
# - [ ] Every placeholder (`?`, `_Write your answer here._`, `Replace with your name`) has been replaced with real work.
# - [ ] **Runtime → Restart runtime and run all** completes with no unintended errors.
# - [ ] The AI-use note in the Reflection section is complete, even if it says no AI tools were used.
# - [ ] The notebook is saved as a personal Drive copy named `HW1_lastname_firstname.ipynb` in `03_Assignments`.
# - [ ] The requested file or link has been submitted on Brightspace.

# %% [markdown]
# ## Rubric
#
# Out of 20 points. Point values may be adjusted to match the version of this assignment posted on Brightspace.
#
# | Criteria | Points | What earns full credit |
# |---|---:|---|
# | Part A — Computer systems vocabulary | 4 | Each answer (A1–A3) uses a real, personal example (not the class kitchen analogy), is written in complete sentences, and correctly distinguishes the target concepts (hardware/software, input/processing/output, memory/storage). |
# | Part B — Notebooks, runtime state, and print | 6 | The `NameError` diagnosis correctly names the error and its cause; the corrected cell runs without error and prints the student's real name; the four-variable exercise uses the correct type for each variable and prints every value with its `type()`; the restart-and-run-all confirmation is specific and honest. |
# | Part C — Variables and basic types | 6 | Predictions are recorded before running any code and match the confirmed `type()` result; the personal-profile exercise uses the correct type for each variable; the `8` vs. `"8"` explanation shows genuine reasoning about why Python separates numbers from text. |
# | Reflection and AI-use note | 2 | Both reflection questions are specific rather than generic, and the AI-use note is present and follows the syllabus format (or states plainly that no AI tools were used). |
# | Submission mechanics | 2 | All placeholders are replaced, the notebook runs top to bottom after Restart runtime and run all, and the file is named and filed correctly. |
